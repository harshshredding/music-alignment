# %% [markdown]
# This notebook contains code to run evaluations on everything inside `work` directory. The work directory contains all four types of files :
# - performance midi
# - performance wav
# - score midi
# - score wav

# %%
import os,sys,time
import numpy as np
from scipy.io import wavfile
import sklearn
from IPython.display import Audio
import musiclib, database
# %load_ext cython
# Out:
# The cython extension is already loaded. To reload it, use:
#   %reload_ext cython

# %%
# %%cython
# import numpy as np
# cimport numpy as np
# cimport cython
# from libc.math cimport sqrt
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# cpdef align(float[:,:] sig1,float[:,:] sig2):
#     cdef int d = sig1.shape[1]
#     cdef int len1 = sig1.shape[0]
#     cdef int len2 = sig2.shape[0]
#     cdef np.ndarray[np.float32_t, ndim=2] npL = np.empty((len1,len2), dtype=np.float32)
#     cdef np.ndarray[np.float32_t, ndim=2] npP = np.empty((len1,len2), dtype=np.float32)
#
#     cdef float[:,:] L = npL
#     cdef float[:,:] P = npP
#
#     cdef float cost,tmp
#     cdef int j,k,i
#     for j in range(0,len1):
#         for k in range(0,len2):
#             cost = 0
#             for i in range(d):
#                 tmp = sig1[j,i] - sig2[k,i]
#                 cost += tmp * tmp
#             cost = sqrt(cost)
#
#             if j == 0 and k == 0:
#                 L[j,k] = cost
#                 P[j,k] = 3
#             elif k == 0:
#                 L[j,k] = cost + L[j-1,k]
#                 P[j,k] = 2
#             elif j == 0:
#                 L[j,k] = cost + L[j,k-1]
#                 P[j,k] = 1
#             else: # j, k > 0
#                 if L[j-1,k] < L[j,k-1] and L[j-1,k] < L[j-1,k-1]: # insertion (up)
#                     P[j,k] = 1
#                     L[j,k] = cost + L[j-1,k]
#                 elif L[j,k-1] < L[j-1,k-1]: # deletion (left)
#                     P[j,k] = 2
#                     L[j,k] = cost + L[j,k-1]
#                 else: # match (up left)
#                     P[j,k] = 3
#                     L[j,k] = cost + L[j-1,k-1]
#
#     return npL,npP
#
# def traceback_loss(float[:,:] sig1,float[:,:] sig2, float[:,:] L):
#     sig12 = np.zeros(sig2.shape) # align 1 onto 2
#     cdef int j = sig1.shape[0]-1
#     cdef int k = sig2.shape[0]-1
#     A = []
#     C = []
#     cdef float cost,tmp
#     while True:
#         if j == 0 and k == 0:
#             A.append((0,0))
#             C.append(L[0,0])
#             break # got back to the beginning
#
#         cost = 0
#         for i in range(sig1.shape[1]):
#             tmp = sig1[j,i] - sig2[k,i]
#             cost += tmp * tmp
#         cost = sqrt(cost)
#
#         if j>0 and k>0 and L[j,k] == L[j-1,k-1] + cost: # progress
#             A.append((j,k))
#             C.append(L[j,k])
#             j -= 1
#             k -= 1
#         elif k>0 and L[j,k] == L[j,k-1] + cost: # stay sig2
#             A.append((j,k))
#             C.append(L[j,k])
#             k -= 1
#         elif j>0 and L[j,k] == L[j-1,k] + cost: # stay sig1
#             A.append((j,k))
#             C.append(L[j,k])
#             j -= 1
#         else:
# #             print 'j',j
# #             print 'k',k
# #             print 'cost',cost
# #             print 'L[j,k]',L[j,k]
# #             print 'L[j,k]-cost',L[j,k]-cost
# #             print 'L[j,k-1]',L[j,k-1]
# #             print 'L[j-1,k]',L[j-1,k]
# #             print 'L[j-1,k-1]',L[j-1,k-1]
#             assert False
#
#     return list(reversed(A)),list(reversed(C))

# %%
# Function that aligns two music pieces in the audio domain and then evaluates the alignment, giving
# a score along with charts illustrating the alignment error.
# score_wav : the kern score wav file path
# score_midi : the kern score midi file path
# performance_wav : the maestro wav file path
# performance_midi : the maestro midi file path
# score_length : length(in seconds) that the score will be trimmed to before alignment
# performance_length : length(in seconds) that the performance will be trimmed to before alignment
def alignAndEvaluate(score_wav, score_midi, performance_wav, performance_midi, score_length=None, performance_length=None):
    window_size=2048
    stride=512
    cutoff=int(50*(window_size/2048.)) # only consider first 50 bins of spectrum for analysis
    record = performance_wav
    synth = score_wav
    
    # Read maestro file
    fs, data1 = wavfile.read(record)
    left_pad = 1*fs
    right_pad = 0*fs
    # Trim if necessary
    if performance_length is not None:
        data1 = data1[0:int(performance_length*fs)] 
    data1 = np.concatenate((np.zeros((left_pad,2)),data1),axis=0)
    frep1 = database.featurize(data1,fs,musiclib.feature,window_size,stride=stride,normalize=False)
    
    # Read score file
    fs, data2 = wavfile.read(synth)
    if not (score_length is None):
        data2 = data2[0:int(score_length*fs)]
    data2 = np.concatenate((np.zeros((left_pad,2)),data2),axis=0)
    frep2 = database.featurize(data2,fs,musiclib.feature,window_size,stride=stride,normalize=False)

    # Align signals
    start = time.time()
    L,P = align(frep1[0:cutoff].T.astype(np.float32),frep2[0:cutoff].T.astype(np.float32))
    end = time.time()
    print('Elapsed time: ' + str(end - start))

    # Find optimal path
    path,costs = traceback_loss(frep1[0:cutoff].T.astype(np.float32),frep2[0:cutoff].T.astype(np.float32),L)
    path1 = np.array([x[0] for x in path])
    path2 = np.array([x[1] for x in path])

    if path1[-1] >= path2[-1]:
        longer_piece_length = path1[-1]
    else:
        longer_piece_length = path2[-1]

    # Find corresponding onsets on the performance
    notes_onsets_offsets_2 = musiclib.load_midi(score_midi)
    for i, e in list(enumerate(notes_onsets_offsets_2)):
        notes_onsets_offsets_2[i] = (e[0], (e[1]*fs + left_pad)/stride, (e[2]*fs + left_pad)/stride)

    notes_onsets_offsets_1 = []    
    for note, onset, offset in notes_onsets_offsets_2:
        if (onset > longer_piece_length - right_pad/stride) or (offset > longer_piece_length - right_pad/stride):
            break
        sig2_onset_index = np.argmax(path2>=int(onset))
        sig2_offset_index = np.argmax(path2>=int(offset))
        sig1_onset = path1[sig2_onset_index]
        sig1_offset = path1[sig2_offset_index]
        notes_onsets_offsets_1.append((note, sig1_onset, sig1_offset))
    notes_onsets_offsets_1 = np.array(notes_onsets_offsets_1)

    # Find the correct onsets from the maestro midi file wtc1p19.mid
    notes_onsets_offsets_correct = musiclib.load_midi(performance_midi)

    for i, e in list(enumerate(notes_onsets_offsets_correct)):
        notes_onsets_offsets_correct[i] = (e[0], (e[1]*fs + left_pad)/stride, (e[2]*fs + left_pad)/stride)

    notes_onsets_offsets_correct_temp = []

    for note, onset, offset in notes_onsets_offsets_correct:
        if (onset > longer_piece_length - right_pad/stride) or (offset > longer_piece_length - right_pad/stride):
            break
        notes_onsets_offsets_correct_temp.append((note, onset, offset))
    notes_onsets_offsets_correct = np.array(notes_onsets_offsets_correct_temp)
    # Need to convert to int just like we did while aligning
    notes_onsets_offsets_correct = notes_onsets_offsets_correct.astype(int)

    longer_data = data1 if data1[:,0].shape[0] >= data2[:,0].shape[0] else data2
    x = np.zeros((longer_data[:,0].shape[0], 128), dtype=bool)
    y = np.zeros((longer_data[:,0].shape[0], 128), dtype=bool)

    # Discretize maestro 
    for note, onset, offset in notes_onsets_offsets_correct:
        onset = int(onset*stride)
        offset = int(offset*stride)
        for i in range(onset, offset):
            if (onset > x.shape[0] or offset > x.shape[0]):
                print("onset : " + str(onset) + " offset " + str(offset))
                break
            else:
                x[i][int(note)] = True  

    # Discretize aligned midi         
    for note, onset, offset in notes_onsets_offsets_1:
        onset = int(onset*stride)
        offset = int(offset*stride)
        for i in range(onset, offset):
            if (onset > y.shape[0] or offset > y.shape[0]):
                print("onset : " + str(onset) + " offset " + str(offset))
                break
            y[i][int(note)] = True

    # Error conditions :
    # 1) Something is playing in maestro and nothing is playing in alignment
    # 2) Something is playing in alignment and nothing is playing in maestro
    # This can be efficiently calculated using xor.

    z = np.logical_xor(x[::512], y[::512])
    print("Alignment Error: ", np.sum(z)) # total number of errors
    print("Errors per second: ", np.sum(z)/(44100/512.)) # total number of errors
    print("Errors per frame: ", np.sum(z)/len(z)) # total number of errors
    return {'name': performance_wav, 'alignment_error': np.sum(z), 'error_per_second': np.sum(z)/(44100/512.), 'error_per_frame': np.sum(z)/len(z)}
    
    
alignAndEvaluate('./test/bwv854_prelude_score.wav', './test/bwv854_prelude_score.midi',
                 './test/066_bwv854.wav', './test/066_bwv854.mid', 20, 16)
# Out:
# /Users/harshverma/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# Elapsed time: 0.13527822494506836
# Alignment Error:  1456
# Errors per second:  16.904126984126986
# Errors per frame:  0.8048645660585959
# {'name': './test/066_bwv854.wav',
#  'alignment_error': 1456,
#  'error_per_second': 16.904126984126986,
#  'error_per_frame': 0.8048645660585959}

# %%
alignAndEvaluate('./work/bwv857_fugue_score.wav', './work/bwv857_fugue_score.midi',
                 './work/080_bwv857_fugue.wav', './work/080_bwv857_fugue.midi')
# Out:
# /Users/harshverma/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# Elapsed time: 31.1730899810791
# Alignment Error:  23709
# Errors per second:  275.2609523809524
# Errors per frame:  1.060378371125721

# %%
# Get the data-structure which categorizes files in a way
# that we can use to start evaluation
piece_to_files = musiclib.get_piece_to_files_map()
# Out:
# bwv866_prelude {'kern': ['./work/bwv866_prelude_score.wav', './work/bwv866_prelude_score.midi']}
# bwv861_prelude {'kern': ['./work/bwv861_prelude_score.wav', './work/bwv861_prelude_score.midi']}
# bwv872_fugue {'kern': ['./work/bwv872_fugue_score.wav', './work/bwv872_fugue_score.midi']}
# bwv878_prelude {'kern': ['./work/bwv878_prelude_score.wav', './work/bwv878_prelude_score.midi']}
# bwv882_fugue {'kern': ['./work/bwv882_fugue_score.midi', './work/bwv882_fugue_score.wav']}
# bwv879_prelude {'kern': ['./work/bwv879_prelude_score.wav', './work/bwv879_prelude_score.midi']}
# bwv866_fugue {'kern': ['./work/bwv866_fugue_score.wav', './work/bwv866_fugue_score.midi']}
# bwv869_prelude {'kern': ['./work/bwv869_prelude_score.wav', './work/bwv869_prelude_score.midi']}
# bwv869_fugue {'kern': ['./work/bwv869_fugue_score.midi', './work/bwv869_fugue_score.wav']}
# bwv859_prelude {'kern': ['./work/bwv859_prelude_score.midi', './work/bwv859_prelude_score.wav']}
# bwv878_fugue {'kern': ['./work/bwv878_fugue_score.wav', './work/bwv878_fugue_score.midi']}
# bwv861_fugue {'kern': ['./work/bwv861_fugue_score.midi', './work/bwv861_fugue_score.wav']}
# bwv872_prelude {'kern': ['./work/bwv872_prelude_score.wav', './work/bwv872_prelude_score.midi']}
# bwv879_fugue {'kern': ['./work/bwv879_fugue_score.midi', './work/bwv879_fugue_score.wav']}
# bwv881_fugue {'kern': ['./work/bwv881_fugue_score.wav', './work/bwv881_fugue_score.midi']}
# bwv886_fugue {'kern': ['./work/bwv886_fugue_score.midi', './work/bwv886_fugue_score.wav']}
# bwv890_fugue {'kern': ['./work/bwv890_fugue_score.midi', './work/bwv890_fugue_score.wav']}

# %%
# evaluate all pieces and store results in the following variable
evaluation_results = []
for piece in piece_to_files:
    all_files = piece_to_files[piece]
    kern_files = all_files['kern']
    maestro_list_of_lists = all_files['maestro']
    if len(kern_files) > 0 and len(maestro_files) > 0:
        kern_wav_file = list(filter(lambda x : '.wav' in x,kern_files))[0]
        kern_score_file = list(filter(lambda x : '.mid' in x,kern_files))[0]
        print(kern_wav_file)
        print(kern_score_file)
        for maestro_files in maestro_list_of_lists:
            maestro_wav_file = list(filter(lambda x : '.wav' in x,maestro_files))[0]
            maestro_midi_file = list(filter(lambda x : '.mid' in x,maestro_files))[0]
            result = alignAndEvaluate(kern_wav_file, kern_score_file, maestro_wav_file, maestro_midi_file)
            evaluation_results.append(result)
            print('----------------------------------------------')
# Out:
# ./work/bwv863_prelude_score.wav
# ./work/bwv863_prelude_score.midi
# /Users/harshverma/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/io/wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# Elapsed time: 1.8123540878295898
# Alignment Error:  4934
# Errors per second:  57.283628117913835
# Errors per frame:  0.5436315557514323
# ----------------------------------------------
# Elapsed time: 1.7922728061676025
# Alignment Error:  40785
# Errors per second:  473.512925170068
# Errors per frame:  4.413005842891149
# ----------------------------------------------
# Elapsed time: 1.9891717433929443
# Alignment Error:  9364
# Errors per second:  108.71582766439909
# Errors per frame:  0.9926852538958973
# ----------------------------------------------
# ./work/bwv874_fugue_score.wav
# ./work/bwv874_fugue_score.midi
# Elapsed time: 13.699948072433472
# Alignment Error:  16699
# Errors per second:  193.87501133786847
# Errors per frame:  0.984959301639731
# ----------------------------------------------
# Elapsed time: 2.33571195602417
# Alignment Error:  15461
# Errors per second:  179.50185941043082
# Errors per frame:  1.3468943287742834
# ----------------------------------------------
# Elapsed time: 9.55035924911499
# Alignment Error:  20751
# Errors per second:  240.9186394557823
# Errors per frame:  1.201981000926784
# ----------------------------------------------
# Elapsed time: 8.071532964706421
# Alignment Error:  16043
# Errors per second:  186.25886621315192
# Errors per frame:  1.1039774291219377
# ----------------------------------------------
# Elapsed time: 9.367178916931152
# Alignment Error:  87176
# Errors per second:  1012.1113832199546
# Errors per frame:  5.362366980377684
# ----------------------------------------------
# ./work/bwv887_prelude_score.wav
# ./work/bwv887_prelude_score.midi
# Elapsed time: 4.447849988937378
# Alignment Error:  11719
# Errors per second:  136.05732426303854
# Errors per frame:  1.1605268369974253
# ----------------------------------------------
# ./work/bwv850_fugue_score.wav
# ./work/bwv850_fugue_score.midi
# Elapsed time: 10.643995761871338
# Alignment Error:  52371
# Errors per second:  608.0261224489795
# Errors per frame:  2.3422782772038104
# ----------------------------------------------
# Elapsed time: 10.048401355743408
# Alignment Error:  45634
# Errors per second:  529.8097052154195
# Errors per frame:  2.0409678429267855
# ----------------------------------------------
# Elapsed time: 14.32425594329834
# Alignment Error:  67031
# Errors per second:  778.2283900226757
# Errors per frame:  2.99700438165072
# ----------------------------------------------
# ./work/bwv857_prelude_score.wav
# ./work/bwv857_prelude_score.midi
# Elapsed time: 3.242198944091797
# Alignment Error:  15637
# Errors per second:  181.54521541950115
# Errors per frame:  1.6341310481764029
# ----------------------------------------------
# Elapsed time: 5.579896688461304
# Alignment Error:  80483
# Errors per second:  934.4058049886621
# Errors per frame:  4.921905577299413
# ----------------------------------------------
# Elapsed time: 3.1722781658172607
# Alignment Error:  8281
# Errors per second:  96.14222222222222
# Errors per frame:  0.8895692340745515
# ----------------------------------------------
# Elapsed time: 4.272931814193726
# Alignment Error:  62900
# Errors per second:  730.2675736961452
# Errors per frame:  5.010355265254102
# ----------------------------------------------
# Elapsed time: 4.428765296936035
# Alignment Error:  10783
# Errors per second:  125.19038548752835
# Errors per frame:  0.9029475799698543
# ----------------------------------------------
# Elapsed time: 3.8878190517425537
# Alignment Error:  55685
# Errors per second:  646.5015873015873
# Errors per frame:  5.037998733375554
# ----------------------------------------------
# Elapsed time: 3.69874906539917
# Alignment Error:  10013
# Errors per second:  116.25070294784581
# Errors per frame:  1.0161355794601177
# ----------------------------------------------
# ./work/bwv862_fugue_score.wav
# ./work/bwv862_fugue_score.midi
# Elapsed time: 8.156375169754028
# Alignment Error:  11042
# Errors per second:  128.19736961451247
# Errors per frame:  0.8086415232515562
# ----------------------------------------------
# Elapsed time: 8.881948709487915
# Alignment Error:  16304
# Errors per second:  189.28907029478458
# Errors per frame:  1.1939948736726473
# ----------------------------------------------
# ./work/bwv883_fugue_score.wav
# ./work/bwv883_fugue_score.midi
# Elapsed time: 18.194773197174072
# Alignment Error:  56259
# Errors per second:  653.1657142857143
# Errors per frame:  2.620353982300885
# ----------------------------------------------
# Elapsed time: 28.618278980255127
# Alignment Error:  109266
# Errors per second:  1268.5757823129252
# Errors per frame:  4.299102927289896
# ----------------------------------------------
# Elapsed time: 25.19385004043579
# Alignment Error:  19603
# Errors per second:  227.59038548752835
# Errors per frame:  0.8719419980428788
# ----------------------------------------------
# Elapsed time: 18.617815256118774
# Alignment Error:  15285
# Errors per second:  177.45850340136053
# Errors per frame:  0.7121558030098308
# ----------------------------------------------
# Elapsed time: 16.81331992149353
# Alignment Error:  20840
# Errors per second:  241.95192743764173
# Errors per frame:  0.9709733028933514
# ----------------------------------------------
# ./work/bwv852_prelude_score.wav
# ./work/bwv852_prelude_score.midi
# Elapsed time: 22.96473789215088
# Alignment Error:  26634
# Errors per second:  309.22013605442174
# Errors per frame:  1.230548881907226
# ----------------------------------------------
# ./work/bwv846_fugue_score.wav
# ./work/bwv846_fugue_score.midi
# Elapsed time: 3.513927936553955
# Alignment Error:  30671
# Errors per second:  356.08961451247166
# Errors per frame:  3.3428882833787466
# ----------------------------------------------
# ./work/bwv862_prelude_score.wav
# ./work/bwv862_prelude_score.midi
# Elapsed time: 1.9246819019317627
# Alignment Error:  6305
# Errors per second:  73.20090702947846
# Errors per frame:  0.9719438877755511
# ----------------------------------------------
# Elapsed time: 2.098655939102173
# Alignment Error:  8538
# Errors per second:  99.12598639455783
# Errors per frame:  1.2435187882318672
# ----------------------------------------------
# ./work/bwv884_fugue_score.wav
# ./work/bwv884_fugue_score.midi
# Elapsed time: 2.185728073120117
# Alignment Error:  21499
# Errors per second:  249.60290249433106
# Errors per frame:  3.013596860106532
# ----------------------------------------------
# ./work/bwv856_prelude_score.wav
# ./work/bwv856_prelude_score.midi
# Elapsed time: 1.7506401538848877
# Alignment Error:  5881
# Errors per second:  68.27827664399094
# Errors per frame:  0.8251718815771012
# ----------------------------------------------
# ./work/bwv858_fugue_score.wav
# ./work/bwv858_fugue_score.midi
# Elapsed time: 5.865176200866699
# Alignment Error:  10472
# Errors per second:  121.57968253968254
# Errors per frame:  0.9344993753346421
# ----------------------------------------------
# Elapsed time: 6.0975258350372314
# Alignment Error:  10824
# Errors per second:  125.66639455782312
# Errors per frame:  0.8610978520286396
# ----------------------------------------------
# ./work/bwv867_prelude_score.wav
# ./work/bwv867_prelude_score.midi
# Elapsed time: 3.0861082077026367
# Alignment Error:  26046
# Errors per second:  302.3934693877551
# Errors per frame:  1.7267303102625298
# ----------------------------------------------
# Elapsed time: 3.2513508796691895
# Alignment Error:  26331
# Errors per second:  305.7023129251701
# Errors per frame:  1.6746804045029575
# ----------------------------------------------
# Elapsed time: 3.2903668880462646
# Alignment Error:  24023
# Errors per second:  278.906485260771
# Errors per frame:  1.5051061963536119
# ----------------------------------------------
# Elapsed time: 2.778749942779541
# Alignment Error:  24759
# Errors per second:  287.45142857142855
# Errors per frame:  1.8325068462734069
# ----------------------------------------------
# ./work/bwv857_fugue_score.wav
# ./work/bwv857_fugue_score.midi
# Elapsed time: 23.36777400970459
# Alignment Error:  93068
# Errors per second:  1080.5173696145125
# Errors per frame:  4.161137440758294
# ----------------------------------------------
# Elapsed time: 0.485929012298584
# Alignment Error:  594
# Errors per second:  6.896326530612245
# Errors per frame:  0.02656648329531732
# ----------------------------------------------
# Elapsed time: 21.3893620967865
# Alignment Error:  19235
# Errors per second:  223.31791383219954
# Errors per frame:  0.8602799767431459
# ----------------------------------------------
# Elapsed time: 22.563745975494385
# Alignment Error:  20921
# Errors per second:  242.89233560090702
# Errors per frame:  0.9356858535712689
# ----------------------------------------------
# Elapsed time: 23.061392784118652
# Alignment Error:  94552
# Errors per second:  1097.746575963719
# Errors per frame:  4.2274881516587675
# ----------------------------------------------
# Elapsed time: 20.382210969924927
# Alignment Error:  23709
# Errors per second:  275.2609523809524
# Errors per frame:  1.060378371125721
# ----------------------------------------------
# Elapsed time: 0.4397590160369873
# Alignment Error:  727
# Errors per second:  8.440453514739229
# Errors per frame:  0.03251487096918467
# ----------------------------------------------
# ./work/bwv853_prelude_score.wav
# ./work/bwv853_prelude_score.midi
# Elapsed time: 12.990885972976685
# Alignment Error:  103395
# Errors per second:  1200.413605442177
# Errors per frame:  4.936264680607276
# ----------------------------------------------
# Elapsed time: 12.749129056930542
# Alignment Error:  102156
# Errors per second:  1186.028843537415
# Errors per frame:  4.907571099154497
# ----------------------------------------------
# Elapsed time: 13.413002014160156
# Alignment Error:  26337
# Errors per second:  305.77197278911564
# Errors per frame:  1.2500949307005886
# ----------------------------------------------
# Elapsed time: 13.08735203742981
# Alignment Error:  105022
# Errors per second:  1219.3030385487527
# Errors per frame:  4.9424443503223685
# ----------------------------------------------
# Elapsed time: 10.82488489151001
# Alignment Error:  92501
# Errors per second:  1073.9345124716554
# Errors per frame:  5.195517861154797
# ----------------------------------------------
# ./work/bwv873_fugue_score.wav
# ./work/bwv873_fugue_score.midi
# Elapsed time: 6.713760137557983
# Alignment Error:  14516
# Errors per second:  168.53043083900226
# Errors per frame:  1.1004472746569631
# ----------------------------------------------
# ./work/bwv892_fugue_score.wav
# ./work/bwv892_fugue_score.midi
# Elapsed time: 18.721708059310913
# Alignment Error:  26417
# Errors per second:  306.7007709750567
# Errors per frame:  1.2405842021226636
# ----------------------------------------------
# Elapsed time: 19.303915977478027
# Alignment Error:  106485
# Errors per second:  1236.2884353741497
# Errors per frame:  4.880155820348304
# ----------------------------------------------
# ./work/bwv849_prelude_score.wav
# ./work/bwv849_prelude_score.midi
# Elapsed time: 9.709232091903687
# Alignment Error:  79504
# Errors per second:  923.0396371882086
# Errors per frame:  5.207230809536285
# ----------------------------------------------
# Elapsed time: 7.267583131790161
# Alignment Error:  10393
# Errors per second:  120.66249433106576
# Errors per frame:  0.7756548996193746
# ----------------------------------------------
# Elapsed time: 7.4817421436309814
# Alignment Error:  9814
# Errors per second:  113.94031746031746
# Errors per frame:  0.7324427196059408
# ----------------------------------------------
# Elapsed time: 9.761320114135742
# Alignment Error:  69477
# Errors per second:  806.6263945578231
# Errors per frame:  4.62009575741455
# ----------------------------------------------
# ./work/bwv885_prelude_score.wav
# ./work/bwv885_prelude_score.midi
# Elapsed time: 2.3764290809631348
# Alignment Error:  10290
# Errors per second:  119.46666666666667
# Errors per frame:  0.7954545454545454
# ----------------------------------------------
# Elapsed time: 2.8269951343536377
# Alignment Error:  15414
# Errors per second:  178.95619047619047
# Errors per frame:  0.9977344811961939
# ----------------------------------------------
# Elapsed time: 0.043514251708984375
# Alignment Error:  434
# Errors per second:  5.038730158730159
# Errors per frame:  0.11197110423116616
# ----------------------------------------------
# Elapsed time: 2.544977903366089
# Alignment Error:  16051
# Errors per second:  186.35174603174602
# Errors per frame:  1.1551637279596978
# ----------------------------------------------
# ./work/bwv855_prelude_score.wav
# ./work/bwv855_prelude_score.midi
# Elapsed time: 7.344475269317627
# Alignment Error:  20708
# Errors per second:  240.419410430839
# Errors per frame:  1.6562425017995681
# ----------------------------------------------
# ./work/bwv885_fugue_score.wav
# ./work/bwv885_fugue_score.midi
# Elapsed time: 12.844636917114258
# Alignment Error:  26018
# Errors per second:  302.0683900226757
# Errors per frame:  1.5781875530753366
# ----------------------------------------------
# Elapsed time: 10.271691083908081
# Alignment Error:  17494
# Errors per second:  203.1049433106576
# Errors per frame:  1.1220575973317939
# ----------------------------------------------
# Elapsed time: 10.04407787322998
# Alignment Error:  19470
# Errors per second:  226.04625850340136
# Errors per frame:  1.2487973831056378
# ----------------------------------------------
# Elapsed time: 2.8791699409484863
# Alignment Error:  18210
# Errors per second:  211.41768707482993
# Errors per frame:  1.1679815278045027
# ----------------------------------------------
# ./work/bwv856_fugue_score.wav
# ./work/bwv856_fugue_score.midi
# Elapsed time: 1.8678181171417236
# Alignment Error:  7402
# Errors per second:  85.93705215419502
# Errors per frame:  1.1189720332577475
# ----------------------------------------------
# ./work/bwv850_prelude_score.wav
# ./work/bwv850_prelude_score.midi
# Elapsed time: 1.9285991191864014
# Alignment Error:  22567
# Errors per second:  262.002358276644
# Errors per frame:  3.1557824080548174
# ----------------------------------------------
# Elapsed time: 2.765277147293091
# Alignment Error:  18701
# Errors per second:  217.1181859410431
# Errors per frame:  1.8359513057137247
# ----------------------------------------------
# Elapsed time: 1.6696338653564453
# Alignment Error:  6615
# Errors per second:  76.8
# Errors per frame:  1.0721231766612642
# ----------------------------------------------
# ./work/bwv893_fugue_score.wav
# ./work/bwv893_fugue_score.midi
# Elapsed time: 4.804416656494141
# Alignment Error:  11532
# Errors per second:  133.88625850340136
# Errors per frame:  1.0515181909364457
# ----------------------------------------------
# Elapsed time: 4.14146089553833
# Alignment Error:  11093
# Errors per second:  128.7894784580499
# Errors per frame:  1.0114890124920215
# ----------------------------------------------
# Elapsed time: 4.069430112838745
# Alignment Error:  13186
# Errors per second:  153.08916099773242
# Errors per frame:  1.2023342755539346
# ----------------------------------------------
# ./work/bwv860_prelude_score.wav
# ./work/bwv860_prelude_score.midi
# Elapsed time: 0.6839241981506348
# Alignment Error:  4764
# Errors per second:  55.309931972789116
# Errors per frame:  1.046572934973638
# ----------------------------------------------
# Elapsed time: 0.6797819137573242
# Alignment Error:  4935
# Errors per second:  57.2952380952381
# Errors per frame:  1.0964230171073095
# ----------------------------------------------
# Elapsed time: 0.7593958377838135
# Alignment Error:  14429
# Errors per second:  167.5203628117914
# Errors per frame:  2.887532519511707
# ----------------------------------------------
# Elapsed time: 0.7065467834472656
# Alignment Error:  4477
# Errors per second:  51.977868480725625
# Errors per frame:  0.9543807290556384
# ----------------------------------------------
# Elapsed time: 0.6933407783508301
# Alignment Error:  4760
# Errors per second:  55.263492063492066
# Errors per frame:  1.0632119723028814
# ----------------------------------------------
# Elapsed time: 0.6755211353302002
# Alignment Error:  4635
# Errors per second:  53.81224489795918
# Errors per frame:  1.0345982142857142
# ----------------------------------------------
# Elapsed time: 0.6755788326263428
# Alignment Error:  4161
# Errors per second:  48.309115646258505
# Errors per frame:  0.9304561717352415
# ----------------------------------------------
# ./work/bwv875_fugue_score.wav
# ./work/bwv875_fugue_score.midi
# Elapsed time: 4.576667785644531
# Alignment Error:  7925
# Errors per second:  92.00907029478458
# Errors per frame:  0.7891068405854824
# ----------------------------------------------
# Elapsed time: 5.21148681640625
# Alignment Error:  44777
# Errors per second:  519.8599546485261
# Errors per frame:  3.9451101321585904
# ----------------------------------------------
# Elapsed time: 5.139542102813721
# Alignment Error:  7088
# Errors per second:  82.29151927437641
# Errors per frame:  0.6273676756948132
# ----------------------------------------------
# Elapsed time: 4.953943729400635
# Alignment Error:  8309
# Errors per second:  96.46730158730159
# Errors per frame:  0.7624334740319325
# ----------------------------------------------
# ./work/bwv848_fugue_score.wav
# ./work/bwv848_fugue_score.midi
# Elapsed time: 5.766820192337036
# Alignment Error:  13653
# Errors per second:  158.51102040816326
# Errors per frame:  1.2415204146585432
# ----------------------------------------------
# Elapsed time: 7.376244068145752
# Alignment Error:  51509
# Errors per second:  598.0183219954648
# Errors per frame:  3.683423913043478
# ----------------------------------------------
# Elapsed time: 6.2549169063568115
# Alignment Error:  42009
# Errors per second:  487.72353741496596
# Errors per frame:  3.5573714963163687
# ----------------------------------------------
# Elapsed time: 6.303350925445557
# Alignment Error:  13865
# Errors per second:  160.97233560090703
# Errors per frame:  1.156283879576349
# ----------------------------------------------
# Elapsed time: 5.863526821136475
# Alignment Error:  12860
# Errors per second:  149.30430839002267
# Errors per frame:  1.1488297302126138
# ----------------------------------------------
# Elapsed time: 5.799099922180176
# Alignment Error:  12818
# Errors per second:  148.81668934240363
# Errors per frame:  1.164320101734944
# ----------------------------------------------
# Elapsed time: 6.354574918746948
# Alignment Error:  14213
# Errors per second:  165.01260770975057
# Errors per frame:  1.176280724985517
# ----------------------------------------------
# Elapsed time: 6.472938060760498
# Alignment Error:  15545
# Errors per second:  180.47709750566892
# Errors per frame:  1.2616670724778833
# ----------------------------------------------
# Elapsed time: 5.087277173995972
# Alignment Error:  13303
# Errors per second:  154.4475283446712
# Errors per frame:  1.213002644296526
# ----------------------------------------------
# Elapsed time: 5.994151830673218
# Alignment Error:  13882
# Errors per second:  161.1697052154195
# Errors per frame:  1.2203956043956043
# ----------------------------------------------
# Elapsed time: 5.513089895248413
# Alignment Error:  14367
# Errors per second:  166.80054421768708
# Errors per frame:  1.3100209720069298
# ----------------------------------------------
# ./work/bwv848_prelude_score.wav
# ./work/bwv848_prelude_score.midi
# Elapsed time: 3.332331895828247
# Alignment Error:  6554
# Errors per second:  76.09179138321996
# Errors per frame:  0.6677534386143658
# ----------------------------------------------
# Elapsed time: 3.0472970008850098
# Alignment Error:  7421
# Errors per second:  86.15764172335601
# Errors per frame:  0.7560876209882832
# ----------------------------------------------
# Elapsed time: 2.8074469566345215
# Alignment Error:  7569
# Errors per second:  87.87591836734694
# Errors per frame:  0.7711665817626082
# ----------------------------------------------
# Elapsed time: 3.0341079235076904
# Alignment Error:  7357
# Errors per second:  85.41460317460317
# Errors per frame:  0.7495669893020886
# ----------------------------------------------
# Elapsed time: 3.276427984237671
# Alignment Error:  5674
# Errors per second:  65.87501133786849
# Errors per frame:  0.57809475292919
# ----------------------------------------------
# Elapsed time: 3.083031177520752
# Alignment Error:  6967
# Errors per second:  80.88671201814059
# Errors per frame:  0.7098318899643403
# ----------------------------------------------
# Elapsed time: 2.8067610263824463
# Alignment Error:  6740
# Errors per second:  78.25124716553287
# Errors per frame:  0.6867040244523688
# ----------------------------------------------
# Elapsed time: 2.9941909313201904
# Alignment Error:  6732
# Errors per second:  78.15836734693877
# Errors per frame:  0.6858889454915945
# ----------------------------------------------
# Elapsed time: 3.146014928817749
# Alignment Error:  17095
# Errors per second:  198.47256235827663
# Errors per frame:  1.7404805538586845
# ----------------------------------------------
# Elapsed time: 2.9944100379943848
# Alignment Error:  6574
# Errors per second:  76.32399092970522
# Errors per frame:  0.6697911360163016
# ----------------------------------------------
# Elapsed time: 3.6979641914367676
# Alignment Error:  21997
# Errors per second:  255.38467120181406
# Errors per frame:  2.2395642435349217
# ----------------------------------------------
# ./work/bwv884_prelude_score.wav
# ./work/bwv884_prelude_score.midi
# Elapsed time: 2.106841802597046
# Alignment Error:  18652
# Errors per second:  216.5492970521542
# Errors per frame:  2.730493339188991
# ----------------------------------------------
# ./work/bwv854_prelude_score.wav
# ./work/bwv854_prelude_score.midi
# Elapsed time: 3.0950729846954346
# Alignment Error:  32501
# Errors per second:  377.335873015873
# Errors per frame:  3.922399227612841
# ----------------------------------------------
# Elapsed time: 3.107753276824951
# Alignment Error:  8204
# Errors per second:  95.24825396825396
# Errors per frame:  0.9909409348955188
# ----------------------------------------------
# Elapsed time: 2.9351000785827637
# Alignment Error:  7496
# Errors per second:  87.02839002267574
# Errors per frame:  0.9054233603092161
# ----------------------------------------------
# Elapsed time: 2.73860502243042
# Alignment Error:  5857
# Errors per second:  67.99963718820862
# Errors per frame:  0.7074525908926199
# ----------------------------------------------
# Elapsed time: 3.209636926651001
# Alignment Error:  7431
# Errors per second:  86.27374149659865
# Errors per frame:  0.897572170551999
# ----------------------------------------------
# Elapsed time: 3.2292349338531494
# Alignment Error:  34026
# Errors per second:  395.04108843537415
# Errors per frame:  4.106444605358436
# ----------------------------------------------
# ./work/bwv863_fugue_score.wav
# ./work/bwv863_fugue_score.midi
# Elapsed time: 10.583147048950195
# Alignment Error:  74044
# Errors per second:  859.6491609977325
# Errors per frame:  4.5364538659478
# ----------------------------------------------
# Elapsed time: 9.35673213005066
# Alignment Error:  11052
# Errors per second:  128.3134693877551
# Errors per frame:  0.7604761577100392
# ----------------------------------------------
# Elapsed time: 9.416817903518677
# Alignment Error:  12466
# Errors per second:  144.72997732426305
# Errors per frame:  0.8523760683760684
# ----------------------------------------------
# ./work/bwv851_prelude_score.wav
# ./work/bwv851_prelude_score.midi
# Elapsed time: 2.745534896850586
# Alignment Error:  9364
# Errors per second:  108.71582766439909
# Errors per frame:  1.1784545683362697
# ----------------------------------------------
# ./work/bwv847_fugue_score.wav
# ./work/bwv847_fugue_score.midi
# Elapsed time: 3.204746961593628
# Alignment Error:  26822
# Errors per second:  311.4028117913832
# Errors per frame:  2.9647396927158174
# ----------------------------------------------
# ./work/bwv887_fugue_score.wav
# ./work/bwv887_fugue_score.midi
# Elapsed time: 35.405096769332886
# Alignment Error:  26176
# Errors per second:  303.90276643990927
# Errors per frame:  0.8487127942416186
# ----------------------------------------------
# ./work/bwv870_prelude_score.wav
# ./work/bwv870_prelude_score.midi
# Elapsed time: 4.056106090545654
# Alignment Error:  21597
# Errors per second:  250.74068027210885
# Errors per frame:  1.5408818493150684
# ----------------------------------------------
# Elapsed time: 3.696218729019165
# Alignment Error:  16987
# Errors per second:  197.21868480725624
# Errors per frame:  1.3334641651621006
# ----------------------------------------------
# ./work/bwv891_fugue_score.wav
# ./work/bwv891_fugue_score.midi
# Elapsed time: 23.040581703186035
# Alignment Error:  18948
# Errors per second:  219.98585034013607
# Errors per frame:  0.7804275299641665
# ----------------------------------------------
# Elapsed time: 28.442664861679077
# Alignment Error:  24632
# Errors per second:  285.9769614512472
# Errors per frame:  1.0145393138102887
# ----------------------------------------------
# ./work/bwv891_prelude_score.wav
# ./work/bwv891_prelude_score.midi
# Elapsed time: 8.609692096710205
# Alignment Error:  10292
# Errors per second:  119.4898866213152
# Errors per frame:  0.7070138077900666
# ----------------------------------------------
# Elapsed time: 9.615658044815063
# Alignment Error:  12408
# Errors per second:  144.05659863945579
# Errors per frame:  0.8523734285910558
# ----------------------------------------------
# ./work/bwv870_fugue_score.wav
# ./work/bwv870_fugue_score.midi
# Elapsed time: 3.1537232398986816
# Alignment Error:  9555
# Errors per second:  110.93333333333334
# Errors per frame:  1.1029666397321944
# ----------------------------------------------
# Elapsed time: 3.5075459480285645
# Alignment Error:  9108
# Errors per second:  105.74367346938776
# Errors per frame:  1.0513678864134826
# ----------------------------------------------
# ./work/bwv875_prelude_score.wav
# ./work/bwv875_prelude_score.midi
# Elapsed time: 2.9636857509613037
# Alignment Error:  9241
# Errors per second:  107.28780045351473
# Errors per frame:  1.1412868963813758
# ----------------------------------------------
# Elapsed time: 3.557593822479248
# Alignment Error:  23041
# Errors per second:  267.50548752834464
# Errors per frame:  2.7145381715362866
# ----------------------------------------------
# Elapsed time: 2.964660167694092
# Alignment Error:  7744
# Errors per second:  89.90766439909297
# Errors per frame:  0.9564036062739286
# ----------------------------------------------
# Elapsed time: 3.3345820903778076
# Alignment Error:  8421
# Errors per second:  97.76761904761905
# Errors per frame:  0.9717285945072698
# ----------------------------------------------
# ./work/bwv854_fugue_score.wav
# ./work/bwv854_fugue_score.midi
# Elapsed time: 1.504276990890503
# Alignment Error:  6232
# Errors per second:  72.35337868480725
# Errors per frame:  1.0430125523012552
# ----------------------------------------------
# Elapsed time: 1.687572956085205
# Alignment Error:  7462
# Errors per second:  86.63365079365079
# Errors per frame:  1.2378898473788984
# ----------------------------------------------
# Elapsed time: 1.5385758876800537
# Alignment Error:  7570
# Errors per second:  87.8875283446712
# Errors per frame:  1.2669456066945606
# ----------------------------------------------
# Elapsed time: 1.868778944015503
# Alignment Error:  22664
# Errors per second:  263.1285260770975
# Errors per frame:  3.4443768996960484
# ----------------------------------------------
# Elapsed time: 1.5668082237243652
# Alignment Error:  6761
# Errors per second:  78.4950566893424
# Errors per frame:  1.1315481171548116
# ----------------------------------------------
# Elapsed time: 1.7798359394073486
# Alignment Error:  21676
# Errors per second:  251.65786848072563
# Errors per frame:  3.4899372081790374
# ----------------------------------------------
# ./work/bwv888_fugue_score.wav
# ./work/bwv888_fugue_score.midi
# Elapsed time: 2.154770851135254
# Alignment Error:  6610
# Errors per second:  76.74195011337868
# Errors per frame:  0.8953000135446295
# ----------------------------------------------
# ./work/bwv853_fugue_score.wav
# ./work/bwv853_fugue_score.midi
# Elapsed time: 37.585712909698486
# Alignment Error:  127093
# Errors per second:  1475.5468480725624
# Errors per frame:  4.6550802139037435
# ----------------------------------------------
# Elapsed time: 36.95266103744507
# Alignment Error:  19961
# Errors per second:  231.7467573696145
# Errors per frame:  0.7604190476190477
# ----------------------------------------------
# Elapsed time: 46.305673360824585
# Alignment Error:  131424
# Errors per second:  1525.8296598639456
# Errors per frame:  4.6065194532071505
# ----------------------------------------------
# Elapsed time: 50.158315896987915
# Alignment Error:  125331
# Errors per second:  1455.090068027211
# Errors per frame:  4.552359158766482
# ----------------------------------------------
# Elapsed time: 53.545395851135254
# Alignment Error:  128392
# Errors per second:  1490.62820861678
# Errors per frame:  4.617586764970329
# ----------------------------------------------
# ./work/bwv871_prelude_score.wav
# ./work/bwv871_prelude_score.midi
# Elapsed time: 2.505781888961792
# Alignment Error:  6657
# Errors per second:  77.28761904761905
# Errors per frame:  0.9962586052080216
# ----------------------------------------------
# ./work/bwv877_fugue_score.wav
# ./work/bwv877_fugue_score.midi
# Elapsed time: 46.009947061538696
# Alignment Error:  22903
# Errors per second:  265.90331065759636
# Errors per frame:  1.0242386297571664
# ----------------------------------------------
# ./work/bwv880_fugue_score.wav
# ./work/bwv880_fugue_score.midi
# Elapsed time: 8.623468160629272
# Alignment Error:  13374
# Errors per second:  155.27183673469386
# Errors per frame:  1.437600773943889
# ----------------------------------------------
# Elapsed time: 6.669587850570679
# Alignment Error:  34264
# Errors per second:  397.80426303854875
# Errors per frame:  3.680343716433942
# ----------------------------------------------
# ./work/bwv852_fugue_score.wav
# ./work/bwv852_fugue_score.midi
# Elapsed time: 8.932039976119995
# Alignment Error:  10075
# Errors per second:  116.97052154195012
# Errors per frame:  1.0829839836611845
# ----------------------------------------------
# ./work/bwv846_prelude_score.wav
# ./work/bwv846_prelude_score.midi
# Elapsed time: 8.872403860092163
# Alignment Error:  67642
# Errors per second:  785.3220861678004
# Errors per frame:  4.976237769440153
# ----------------------------------------------
# ./work/bwv876_fugue_score.wav
# ./work/bwv876_fugue_score.midi
# Elapsed time: 11.436545848846436
# Alignment Error:  49091
# Errors per second:  569.9453968253969
# Errors per frame:  4.3221517872864945
# ----------------------------------------------
# Elapsed time: 10.36941909790039
# Alignment Error:  8485
# Errors per second:  98.51065759637189
# Errors per frame:  0.7475112324905294
# ----------------------------------------------
# ./work/bwv877_prelude_score.wav
# ./work/bwv877_prelude_score.midi
# Elapsed time: 8.579142808914185
# Alignment Error:  10841
# Errors per second:  125.8637641723356
# Errors per frame:  0.9492994746059544
# ----------------------------------------------
# ./work/bwv860_fugue_score.wav
# ./work/bwv860_fugue_score.midi
# Elapsed time: 22.214816093444824
# Alignment Error:  19441
# Errors per second:  225.70956916099775
# Errors per frame:  1.3676398170946185
# ----------------------------------------------
# Elapsed time: 25.287628889083862
# Alignment Error:  63245
# Errors per second:  734.2730158730159
# Errors per frame:  3.899198520345253
# ----------------------------------------------
# Elapsed time: 22.41621685028076
# Alignment Error:  17687
# Errors per second:  205.34566893424036
# Errors per frame:  1.2326294515297234
# ----------------------------------------------
# Elapsed time: 22.8052077293396
# Alignment Error:  16569
# Errors per second:  192.3657142857143
# Errors per frame:  1.1250763903035241
# ----------------------------------------------
# Elapsed time: 22.62532901763916
# Alignment Error:  19104
# Errors per second:  221.79700680272109
# Errors per frame:  1.3060778013263143
# ----------------------------------------------
# Elapsed time: 20.307757139205933
# Alignment Error:  16205
# Errors per second:  188.13968253968255
# Errors per frame:  1.221083565669505
# ----------------------------------------------
# Elapsed time: 22.80608630180359
# Alignment Error:  18452
# Errors per second:  214.22730158730158
# Errors per frame:  1.251661918328585
# ----------------------------------------------
# ./work/bwv867_fugue_score.wav
# ./work/bwv867_fugue_score.midi
# Elapsed time: 25.068531036376953
# Alignment Error:  16841
# Errors per second:  195.52362811791383
# Errors per frame:  1.2041327041327041
# ----------------------------------------------
# Elapsed time: 7.757290840148926
# Alignment Error:  15139
# Errors per second:  175.76344671201815
# Errors per frame:  1.2108294009437734
# ----------------------------------------------
# Elapsed time: 8.366392135620117
# Alignment Error:  13325
# Errors per second:  154.702947845805
# Errors per frame:  0.9768345429220732
# ----------------------------------------------
# Elapsed time: 8.897212982177734
# Alignment Error:  11055
# Errors per second:  128.3482993197279
# Errors per frame:  0.7527064751140464
# ----------------------------------------------
# ./work/bwv873_prelude_score.wav
# ./work/bwv873_prelude_score.midi
# Elapsed time: 13.431582927703857
# Alignment Error:  26714
# Errors per second:  310.1489342403628
# Errors per frame:  1.1838688233990693
# ----------------------------------------------
# ./work/bwv871_fugue_score.wav
# ./work/bwv871_fugue_score.midi
# Elapsed time: 7.9578728675842285
# Alignment Error:  8986
# Errors per second:  104.32725623582766
# Errors per frame:  0.6355021216407355
# ----------------------------------------------
# ./work/bwv889_fugue_score.wav
# ./work/bwv889_fugue_score.midi
# Elapsed time: 2.9593749046325684
# Alignment Error:  29342
# Errors per second:  340.6599546485261
# Errors per frame:  3.5343290773307636
# ----------------------------------------------
# Elapsed time: 2.837383985519409
# Alignment Error:  27429
# Errors per second:  318.4500680272109
# Errors per frame:  3.4251998001998003
# ----------------------------------------------
# Elapsed time: 2.979818105697632
# Alignment Error:  28299
# Errors per second:  328.5507482993197
# Errors per frame:  3.344640113461766
# ----------------------------------------------
# Elapsed time: 2.943068742752075
# Alignment Error:  28118
# Errors per second:  326.4493424036281
# Errors per frame:  3.3775375375375374
# ----------------------------------------------
# Elapsed time: 3.766573905944824
# Alignment Error:  34383
# Errors per second:  399.185850340136
# Errors per frame:  3.343674025089954
# ----------------------------------------------
# Elapsed time: 2.8749399185180664
# Alignment Error:  25833
# Errors per second:  299.92054421768705
# Errors per frame:  3.172418027753899
# ----------------------------------------------
# ./work/bwv868_fugue_score.wav
# ./work/bwv868_fugue_score.midi
# Elapsed time: 6.305852890014648
# Alignment Error:  11914
# Errors per second:  138.32126984126984
# Errors per frame:  0.972809667673716
# ----------------------------------------------
# ./work/bwv855_fugue_score.wav
# ./work/bwv855_fugue_score.midi
# Elapsed time: 1.6285791397094727
# Alignment Error:  4253
# Errors per second:  49.3772335600907
# Errors per frame:  0.6556189301680284
# ----------------------------------------------

# %%
# print a few results
print(evaluation_results[0:5])
# Out:
# [{'name': './work/105_bwv863_prelude.wav', 'alignment_error': 4934, 'error_per_second': 57.283628117913835, 'error_per_frame': 0.5436315557514323}, {'name': './work/106_bwv863_prelude.wav', 'alignment_error': 40785, 'error_per_second': 473.512925170068, 'error_per_frame': 4.413005842891149}, {'name': './work/104_bwv863_prelude.wav', 'alignment_error': 9364, 'error_per_second': 108.71582766439909, 'error_per_frame': 0.9926852538958973}, {'name': './work/049_bwv874_fugue.wav', 'alignment_error': 16699, 'error_per_second': 193.87501133786847, 'error_per_frame': 0.984959301639731}, {'name': './work/050_bwv874_fugue.wav', 'alignment_error': 15461, 'error_per_second': 179.50185941043082, 'error_per_frame': 1.3468943287742834}]
